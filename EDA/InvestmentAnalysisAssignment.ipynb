# %%
import pandas as pd

# %%
company_df=pd.read_csv("data/companies.txt",sep="\t", encoding = 'ISO-8859-1')
company_df
# Out:
#                                                                                         permalink  \
# /Organization/-Fame                                                                         #fame
# /Organization/-Qounter                                                                   :Qounter
# /Organization/-The-One-Of-Them-Inc-                                        (THE) ONE of THEM,Inc.
# /Organization/0-6-Com                                                                     0-6.com
# /Organization/004-Technologies                                                   004 Technologies
# ...                                                                                           ...
# /Organization/Zznode-Science-And-Technology-Co-Ltd                  ZZNode Science and Technology
# /Organization/Zzzzapp-Com                                                   Zzzzapp Wireless ltd.
# ...

# %%
#company_df.set_index('permalink', inplace=True)
company_df['permalink']=company_df['permalink'].str.lower()

len(company_df.permalink.unique())
# Out:
# 66038

# %%
company_df.head()
# Out:
#                                                   permalink  \
# /Organization/-Fame                                   #fame
# /Organization/-Qounter                             :qounter
# /Organization/-The-One-Of-Them-Inc-  (the) one of them,inc.
# /Organization/0-6-Com                               0-6.com
# /Organization/004-Technologies             004 technologies
#
#                                                                   name  \
# /Organization/-Fame                                 http://livfame.com
# /Organization/-Qounter                          http://www.qounter.com
# /Organization/-The-One-Of-Them-Inc-                http://oneofthem.jp
# /Organization/0-6-Com                               http://www.0-6.com
# /Organization/004-Technologies       http://004gmbh.de/en/004-interact
#
#                                                                           homepage_url  \
# ...

# %%
company_df.columns
# Out:
# Index(['name', 'homepage_url', 'category_list', 'status country_code',
#        'state_code', 'region', 'city', 'founded_at'],
#       dtype='object')

# %%
# identifying null values 
company_df.isnull()
# Out:
#                                                 name  homepage_url  \
# permalink
# #fame                                          False         False
# :Qounter                                       False         False
# (THE) ONE of THEM,Inc.                         False         False
# 0-6.com                                        False         False
# 004 Technologies                               False         False
# ...                                              ...           ...
# ZZNode Science and Technology                  False         False
# Zzzzapp Wireless ltd.                          False         False
# ÃERON                                         False          True
# Ãasys                                         False         False
# Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic  False         False
#
#                                                category_list  \
# permalink
# #fame                                                  False
# ...

# %%
# identifying null values per colums
company_df.isnull().sum()
# Out:
# name                    5058
# homepage_url            3148
# category_list              0
# status country_code     6958
# state_code              8547
# region                  8030
# city                    8028
# founded_at             15221
# dtype: int64

# %%
#columns having at least one missing value = any()
company_df.isnull().any()
# Out:
# name                    True
# homepage_url            True
# category_list          False
# status country_code     True
# state_code              True
# region                  True
# city                    True
# founded_at              True
# dtype: bool

# %%
# summing up missing values (column-wise)
round(100*(company_df.isnull().sum()/len(company_df.index)),2)
# Out:
# name                    7.62
# homepage_url            4.74
# category_list           0.00
# status country_code    10.48
# state_code             12.88
# region                 12.10
# city                   12.10
# founded_at             22.93
# dtype: float64

# %%
# if ypu delete the missing rows , you lose data. 
# if you impute , you introduce bias 

# delete column founded_at
company_df.drop(['founded_at'], axis=1, inplace=True)
company_df.head()
# Out:
#                                                      name  \
# permalink
# #fame                                  http://livfame.com
# :Qounter                           http://www.qounter.com
# (THE) ONE of THEM,Inc.                http://oneofthem.jp
# 0-6.com                                http://www.0-6.com
# 004 Technologies        http://004gmbh.de/en/004-interact
#
#                                                              homepage_url  \
# permalink
# #fame                                                               Media
# :Qounter                Application Platforms|Real Time|Social Network...
# (THE) ONE of THEM,Inc.                                  Apps|Games|Mobile
# 0-6.com                                                       Curated Web
# 004 Technologies                                                 Software
#
#                        category_list status country_code state_code  \
# permalink
# ...

# %%
# Missing values in rows 
company_df[company_df.isnull().sum(axis=1)>3]
# Out:
#                                                                   name  \
# permalink
# (THE) ONE of THEM,Inc.                             http://oneofthem.jp
# Beijing 1000CHI Software Technology            http://www.1000chi.com/
# Beans Around                                   http://beansaround.com/
# 10tracks                                           http://10tracks.com
# 115 network disks                                  http://www.115.com/
# ...                                                                ...
# ZUUMTEL                                         http://www.zuumtel.com
# Zwayo "On-Demand Valet Parking"                    http://www.zwayo.co
# Zyfin                                            http://www.zyfin.com/
# ÃERON                                            http://www.aeron.hu/
# Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic     http://inovatiff.com
#
#                                                                        homepage_url  \
# permalink
# ...

# %%
#len(company_df[company_df['category_list'] != 'operating'])

# %%
company_df=company_df[company_df.isnull().sum(axis=1) <=3]

# %%
company_df.shape
# Out:
# (59336, 7)

# %%
company_df.head()
# Out:
#                                                  name  \
# permalink
# #fame                              http://livfame.com
# :Qounter                       http://www.qounter.com
# 0-6.com                            http://www.0-6.com
# 004 Technologies    http://004gmbh.de/en/004-interact
# 01Games Technology             http://www.01games.hk/
#
#                                                          homepage_url  \
# permalink
# #fame                                                           Media
# :Qounter            Application Platforms|Real Time|Social Network...
# 0-6.com                                                   Curated Web
# 004 Technologies                                             Software
# 01Games Technology                                              Games
#
#                    category_list status country_code state_code  \
# permalink
# #fame                  operating                 IND         16
# ...

# %%
# df of rounds2

rounds_df = pd.read_csv('data/rounds2.csv', encoding = 'unicode_escape')
rounds_df.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
len(rounds_df.company_permalink.unique())
# Out:
# 90247

# %%
rounds_df.shape
# Out:
# (114949, 6)

# %%
rounds_df['company_permalink']=rounds_df['company_permalink'].str.lower()

# %%
len(rounds_df.company_permalink.unique())
# Out:
# 66370
