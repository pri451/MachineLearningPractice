# %%
import nltk
import random
import pandas as pd 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
dataset = pd.read_csv("SMSSpamCollection.txt", sep = "\t", names=["label", "message"])

# %%
dataset.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in dataset.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# #### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print( messages_set)
# Out:
# [(['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18'], 'spam'), (['dun', 'say', 'early', 'hor', '...', 'already', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'usf', 'live', 'around', 'though'], 'ham'), (['freemsg', 'hey', 'darling', 'week', 'word', 'back', 'like', 'fun', 'still', 'xxx', 'std', 'chgs', 'send', '£1.50', 'rcv'], 'spam'), (['even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent'], 'ham'), (['per', 'request', "'melle", 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'callers', 'press', 'copy', 'friends', 'callertune'], 'ham'), (['winner', 'value', 'network', 'customer', 'select', 'receivea', '£900', 'prize', 'reward', 'claim', 'call', '09061701461.', 'claim', 'code', 'kl341', 'valid', 'hours'], 'spam'), (['mobile', 'months', 'entitle', 'update', 'latest', 'colour', 'mobiles', 'camera', 'free', 'call', 'mobile', 'update', 'free', '08002986030'], 'spam'), (['gon', 'home', 'soon', "n't", 'want', 'talk', 'stuff', 'anymore', 'tonight', "'ve", 'cry', 'enough', 'today'], 'ham'), (['six', 'chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', 'csh11', 'send', '87575.', 'cost', '150p/day', '6days', '16+', 'tsandcs', 'apply', 'reply', 'info'], 'spam'), (['urgent', 'week', 'free', 'membership', '£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18'], 'spam'), (["'ve", 'search', 'right', 'word', 'thank', 'breather', 'promise', 'wont', 'take', 'help', 'grant', 'fulfil', 'promise', 'wonderful', 'bless', 'time'], 'ham'), (['date', 'sunday'], 'ham'), (['xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'next', 'txt', 'message', 'click', 'http', '//wap', 'xxxmobilemovieclub.com', 'n=qjkgighjjgcbl'], 'spam'), (['...', 'watch'], 'ham'), (['remember', 'spell', 'name', '...', 'yes', 'naughty', 'make', 'wet'], 'ham'), (['fine', 'that\x92s', 'way', 'feel', 'that\x92s', 'way', 'gota'], 'ham'), (['england', 'macedonia', 'dont', 'miss', 'goals/team', 'news', 'txt', 'national', 'team', '87077', 'england', '87077', 'try', 'wales', 'scotland', '4txt/ú1.20', 'poboxox36504w45wq', '16+'], 'spam'), (['seriously', 'spell', 'name'], 'ham'), (['try', 'months', 'joke'], 'ham'), (['pay', 'first', 'lar', '...', 'stock', 'comin', '...'], 'ham'), (['aft', 'finish', 'lunch', 'str', 'lor', 'ard', 'smth', 'lor', 'finish', 'lunch', 'already'], 'ham'), (['ffffffffff', 'alright', 'way', 'meet', 'sooner'], 'ham'), (['force', 'eat', 'slice', 'really', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know', 'sick', 'turn', 'pizza', 'lol'], 'ham'), (['lol', 'always', 'convince'], 'ham'), (['catch', 'bus', 'fry', 'egg', 'make', 'tea', 'eat', 'mom', 'leave', 'dinner', 'feel', 'love'], 'ham'), (['back', 'amp', "'re", 'pack', 'car', "'ll", 'let', 'know', 'room'], 'ham'), (['ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol'], 'ham'), (['wait', 'still', 'clear', 'sure', 'sarcastic', "n't", 'want', 'live'], 'ham'), (['yeah', 'get', 'apologetic', 'fall', 'actin', 'like', 'spoil', 'child', 'get', 'catch', 'till', "n't", 'badly', 'cheer'], 'ham'), (['tell', 'anything'], 'ham'), (['fear', 'faint', 'housework', 'quick', 'cuppa'], 'ham'), (['thank', 'subscription', 'ringtone', 'mobile', 'charge', '£5/month', 'please', 'confirm', 'reply', 'yes', 'reply', 'charge'], 'spam'), (['yup', '...', 'home', 'look', 'time', 'msg', '...', 'xuhui', 'learn', '2nd', 'may', 'lesson', '8am'], 'ham'), (['oops', "'ll", 'let', 'know', 'roommate'], 'ham'), (['see', 'letter', 'car'], 'ham'), (['anything', 'lor', '...', 'decide', '...'], 'ham'), (['hello', 'saturday', 'texting', 'see', 'decide', 'anything', 'tomo', 'try', 'invite', 'anything'], 'h ...

# %% [markdown]
# #### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
print(get_words_in_messages(messages_set))
# Out:
# ['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...', 'lar', '...', 'joke', 'wif', 'oni', '...', 'free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18', 'dun', 'say', 'early', 'hor', '...', 'already', 'say', '...', 'nah', "n't", 'think', 'usf', 'live', 'around', 'though', 'freemsg', 'hey', 'darling', 'week', 'word', 'back', 'like', 'fun', 'still', 'xxx', 'std', 'chgs', 'send', '£1.50', 'rcv', 'even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent', 'per', 'request', "'melle", 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'set', 'callertune', 'callers', 'press', 'copy', 'friends', 'callertune', 'winner', 'value', 'network', 'customer', 'select', 'receivea', '£900', 'prize', 'reward', 'claim', 'call', '09061701461.', 'claim', 'code', 'kl341', 'valid', 'hours', 'mobile', 'months', 'entitle', 'update', 'latest', 'colour', 'mobiles', 'camera', 'free', 'call', 'mobile', 'update', 'free', '08002986030', 'gon', 'home', 'soon', "n't", 'want', 'talk', 'stuff', 'anymore', 'tonight', "'ve", 'cry', 'enough', 'today', 'six', 'chance', 'win', 'cash', '100', '20,000', 'pound', 'txt', 'csh11', 'send', '87575.', 'cost', '150p/day', '6days', '16+', 'tsandcs', 'apply', 'reply', 'info', 'urgent', 'week', 'free', 'membership', '£100,000', 'prize', 'jackpot', 'txt', 'word', 'claim', '81010', 'www.dbuk.net', 'lccltd', 'pobox', '4403ldnw1a7rw18', "'ve", 'search', 'right', 'word', 'thank', 'breather', 'promise', 'wont', 'take', 'help', 'grant', 'fulfil', 'promise', 'wonderful', 'bless', 'time', 'date', 'sunday', 'xxxmobilemovieclub', 'use', 'credit', 'click', 'wap', 'link', 'next', 'txt', 'message', 'click', 'http', '//wap', 'xxxmobilemovieclub.com', 'n=qjkgighjjgcbl', '...', 'watch', 'remember', 'spell', 'name', '...', 'yes', 'naughty', 'make', 'wet', 'fine', 'that\x92s', 'way', 'feel', 'that\x92s', 'way', 'gota', 'england', 'macedonia', 'dont', 'miss', 'goals/team', 'news', 'txt', 'national', 'team', '87077', 'england', '87077', 'try', 'wales', 'scotland', '4txt/ú1.20', 'poboxox36504w45wq', '16+', 'seriously', 'spell', 'name', 'try', 'months', 'joke', 'pay', 'first', 'lar', '...', 'stock', 'comin', '...', 'aft', 'finish', 'lunch', 'str', 'lor', 'ard', 'smth', 'lor', 'finish', 'lunch', 'already', 'ffffffffff', 'alright', 'way', 'meet', 'sooner', 'force', 'eat', 'slice', 'really', 'hungry', 'tho', 'suck', 'mark', 'get', 'worry', 'know', 'sick', 'turn', 'pizza', 'lol', 'lol', 'always', 'convince', 'catch', 'bus', 'fry', 'egg', 'make', 'tea', 'eat', 'mom', 'leave', 'dinner', 'feel', 'love', 'back', 'amp', "'re", 'pack', 'car', "'ll", 'let', 'know', 'room', 'ahhh', 'work', 'vaguely', 'remember', 'feel', 'like', 'lol', 'wait', 'still', 'clear', 'sure', 'sarcastic', "n't", 'want', 'live', 'yeah', 'get', 'apologetic', 'fall', 'actin', 'like', 'spoil', 'child', 'get', 'catch', 'till', "n't", 'badly', 'cheer', 'tell', 'anything', 'fear', 'faint', 'housework', 'quick', 'cuppa', 'thank', 'subscription', 'ringtone', 'mobile', 'charge', '£5/month', 'please', 'confirm', 'reply', 'yes', 'reply', 'charge', 'yup', '...', 'home', 'look', 'time', 'msg', '...', 'xuhui', 'learn', '2nd', 'may', 'lesson', '8am', 'oops', "'ll", 'let', 'know', 'roommate', 'see', 'letter', 'car', 'anything', 'lor', '...', 'decide', '...', 'hello', 'saturday', 'texting', 'see', 'decide', 'anything', 'tomo', 'try', 'invite', 'anything', 'pls', 'ahead', 'watts', 'want', 'sure', 'great', 'weekend', 'abiola', 'forget', 'tell', 'want', 'need', 'crave', '...', '...', 'love', 'sweet', 'arabian', 'steed', '...', 'mmmmmm', '...', 'yummy', '07732584351', 'rodger', 'burn', 'msg', 'try', 'call', 'reply', 'sms', 'free', 'nokia', 'mobile', 'free', 'camcorder', 'please', 'call', '08000930705', 'delivery', 'tomorrow', 'see', 'great', 'hope', 'like', 'man', 'well', 'endow', 'inch', '...' ...

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):

    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 8393

# %% [markdown]
# #### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
len(test_messages)
# Out:
# 1115

# %% [markdown]
# #### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contains(jurong)': False, 'contains(point)': False, 'contains(crazy..)': False, 'contains(available)': False, 'contains(bugis)': False, 'contains(great)': False, 'contains(world)': False, 'contains(buffet)': False, 'contains(...)': True, 'contains(cine)': False, 'contains(get)': False, 'contains(amore)': False, 'contains(wat)': False, 'contains(lar)': False, 'contains(joke)': False, 'contains(wif)': False, 'contains(oni)': False, 'contains(free)': False, 'contains(entry)': False, 'contains(wkly)': False, 'contains(comp)': False, 'contains(win)': False, 'contains(cup)': False, 'contains(final)': False, 'contains(tkts)': False, 'contains(21st)': False, 'contains(may)': True, 'contains(2005.)': False, 'contains(text)': False, 'contains(87121)': False, 'contains(receive)': False, 'contains(question)': False, 'contains(std)': False, 'contains(txt)': False, 'contains(rate)': False, 'contains(apply)': False, 'contains(08452810075over18)': False, 'contains(dun)': False, 'contains(say)': False, 'contains(early)': False, 'contains(hor)': False, 'contains(already)': False, 'contains(nah)': False, "contains(n't)": False, 'contains(think)': False, 'contains(usf)': False, 'contains(live)': False, 'contains(around)': False, 'contains(though)': False, 'contains(freemsg)': False, 'contains(hey)': False, 'contains(darling)': False, 'contains(week)': False, 'contains(word)': False, 'contains(back)': False, 'contains(like)': False, 'contains(fun)': False, 'contains(still)': False, 'contains(xxx)': False, 'contains(chgs)': False, 'contains(send)': False, 'contains(£1.50)': False, 'contains(rcv)': False, 'contains(even)': True, 'contains(brother)': False, 'contains(speak)': False, 'contains(treat)': False, 'contains(aid)': False, 'contains(patent)': False, 'contains(per)': False, 'contains(request)': False, "contains('melle)": False, 'contains(melle)': False, 'contains(oru)': False, 'contains(minnaminunginte)': False, 'contains(nurungu)': False, 'contains(vettam)': False, 'contains(set)': False, 'contains(callertune)': False, 'contains(callers)': False, 'contains(press)': False, 'contains(copy)': False, 'contains(friends)': False, 'contains(winner)': False, 'contains(value)': False, 'contains(network)': False, 'contains(customer)': False, 'contains(select)': False, 'contains(receivea)': False, 'contains(£900)': False, 'contains(prize)': False, 'contains(reward)': False, 'contains(claim)': False, 'contains(call)': False, 'contains(09061701461.)': False, 'contains(code)': False, 'contains(kl341)': False, 'contains(valid)': False, 'contains(hours)': False, 'contains(mobile)': False, 'contains(months)': False, 'contains(entitle)': False, 'contains(update)': False, 'contains(latest)': False, 'contains(colour)': False, 'contains(mobiles)': False, 'contains(camera)': False, 'contains(08002986030)': False, 'contains(gon)': False, 'contains(home)': False, 'contains(soon)': False, 'contains(want)': False, 'contains(talk)': False, 'contains(stuff)': False, 'contains(anymore)': False, 'contains(tonight)': False, "contains('ve)": False, 'contains(cry)': False, 'contains(enough)': False, 'contains(today)': False, 'contains(six)': False, 'contains(chance)': False, 'contains(cash)': False, 'contains(100)': False, 'contains(20,000)': False, 'contains(pound)': False, 'contains(csh11)': False, 'contains(87575.)': False, 'contains(cost)': False, 'contains(150p/day)': False, 'contains(6days)': False, 'contains(16+)': False, 'contains(tsandcs)': False, 'contains(reply)': False, 'contains(info)': False, 'contains(urgent)': False, 'contains(membership)': False, 'contains(£100,000)': False, 'contains(jackpot)': False, 'contains(81010)': False, 'contains(www.dbuk.net)': False, 'contains(lccltd)': False, 'contains(pobox)': False, 'contains(4403ldnw1a7rw18)': False, 'contains(search)': False, 'contains(right)': False, 'contains(thank)': False, 'contains(breather)': False, 'contains(promise)': False, 'contains(wont)': False, 'contains(take)': False, 'contains(help)': False ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  4457
# Test set size :  1115

# %% [markdown]
# #### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# #### Evaluation

# %%
## - Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.9937177473636976

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.9721973094170404

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#       contains(landline) = True             spam : ham    =    116.8 : 1.0
#        contains(service) = True             spam : ham    =    108.6 : 1.0
#           contains(code) = True             spam : ham    =    108.0 : 1.0
#          contains(await) = True             spam : ham    =    103.5 : 1.0
#          contains(nokia) = True             spam : ham    =    101.8 : 1.0
#         contains(urgent) = True             spam : ham    =     93.5 : 1.0
#            contains(txt) = True             spam : ham    =     90.6 : 1.0
#           contains(draw) = True             spam : ham    =     85.9 : 1.0
#        contains(attempt) = True             spam : ham    =     81.5 : 1.0
#        contains(voucher) = True             spam : ham    =     68.3 : 1.0
#         contains(orange) = True             spam : ham    =     59.5 : 1.0
#           contains(quiz) = True             spam : ham    =     59.5 : 1.0
#           contains(rate) = True             spam : ham    =     59.5 : 1.0
#       contains(delivery) = True             spam : ham    =     59.5 : 1.0
#        contains(private) = True             spam : ham    =     59.5 : 1.0
#           contains(club) = True             spam : ham    =     55.1 : 1.0
#            contains(100) = True             spam : ham    =     55.1 : 1.0
#          contains(video) = True             spam : ham    =     54.2 : 1.0
#         contains(latest) = True             spam : ham    =     51.9 : 1.0
#         contains(select) = True             spam : ham    =     50.0 : 1.0
#         contains(mobile) = True             spam : ham    =     47.9 : 1.0
#            contains(box) = True             spam : ham    =     46.3 : 1.0
#         contains(camera) = True             spam : ham    =     44.4 : 1.0
#       contains(motorola) = True             spam : ham    =     41.9 : 1.0
#         contains(caller) = True             spam : ham    =     41.9 : 1.0
#            contains(opt) = True             spam : ham    =     41.9 : 1.0
#          contains(apply) = True             spam : ham    =     38.7 : 1.0
#           contains(land) = True             spam : ham    =     38.3 : 1.0
#          contains(final) = True             spam : ham    =     38.3 : 1.0
#       contains(customer) = True             spam : ham    =     38.3 : 1.0
#         contains(txting) = True             spam : ham    =     37.5 : 1.0
#        contains(auction) = True             spam : ham    =     37.5 : 1.0
#       contains(sunshine) = True             spam : ham    =     37.5 : 1.0
#         contains(reward) = True             spam : ham    =     37.5 : 1.0
#        contains(receive) = True             spam : ham    =     33.0 : 1.0
#            contains(del) = True             spam : ham    =     33.0 : 1.0
#            contains(dvd) = True             spam : ham    =     33.0 : 1.0
#          contains(offer) = True             spam : ham    =     33.0 : 1.0
#           contains(cash) = True             spam : ham    =     31.8 : 1.0
#         contains(player) = True             spam : ham    =     30.4 : 1.0
#        contains(network) = True             spam : ham    =     29.4 : 1.0
#         contains(todays) = True             spam : ham    =     29.3 : 1.0
#          contains(music) = True             spam : ham    =     29.3 : 1.0
#           contains(user) = True             spam : ham    =     28.6 : 1.0
#            contains(gay) = True             spam : ham    =     28.6 : 1.0
#    contains(information) = True             spam : ham    =     28.6 : 1.0
#        contains(england) = True             spam : ham    =     28.6 : 1.0
#        contains(contact) = True             spam : ham    =     28.0 : 1.0
#           contains(info) = True             spam : ham    =     27.8 : 1.0
#           contains(line) = True             spam : ham    =     26.0 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
